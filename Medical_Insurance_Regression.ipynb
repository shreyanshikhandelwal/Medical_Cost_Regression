# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('insurance.csv')

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]>

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.hist(bins = 30, figsize = (15,10))
plt.show()

# %%
sns.countplot(x='smoker',data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='sex',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.boxplot(df['age'])
plt.show()

# %%
sns.boxplot(df['bmi'])
plt.show()

# %%
sns.boxplot(df['charges'])
plt.show()

# %%
ax = df.charges.plot(kind='hist')
df.charges.plot(kind='kde',ax=ax, secondary_y=True)
plt.xlabel('Charges')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# Probability density of charges.

# %%
sns.displot(data=df,x='charges',hue='smoker',kind='kde')
plt.show()

# %% [markdown]
# Probability density of charges for somkers vs non-smokers. Non-smokers paid very less than smokers.

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,4,1,)
sns.countplot(df['sex'],palette='pastel')
plt.subplot(1,4,2)
sns.countplot(df['children'],palette='cool')
plt.subplot(1,4,3)
sns.countplot(df['smoker'],palette='gnuplot')
plt.subplot(1,4,4)
sns.countplot(df['region'],palette='autumn')

plt.show()

# %%
numeric_columns=df
sns.pairplot(numeric_columns, hue ='smoker',palette='husl')
plt.show()

# %%
sns.scatterplot(data=df, x='age', y='charges',hue='smoker')
plt.show()

# %% [markdown]
# Non-smokers paid less charges in all different age groups.

# %%
sns.scatterplot(data=df, x='bmi', y='charges',hue='smoker')
plt.show()

# %% [markdown]
# For smokers, as BMI increases, charges increase but it is constant for non-smokers.

# %%
sns.barplot(x='children',y='charges',hue='sex',data=df)
plt.show()

# %% [markdown]
# Male paid more than females except women with more than 3 children.

# %%
sns.barplot(x='region',y='bmi',hue='sex',data=df)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x='region',y='charges',data=df)
# Out:
# <AxesSubplot:xlabel='region', ylabel='charges'>

# %% [markdown]
# In north east and north west regions, bmi of men and women is almost same.

# %%
plt.figure(figsize = (20, 5))
sns.countplot(x='region',hue="smoker",data=df)
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x=df['children'],y=df['charges'],hue=df['smoker'])
plt.title('Children wise charges wrt smoking status',fontsize='30')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x=df['bmi'],y=df['charges'],hue=df['smoker'])
plt.title('Bmi wise charges wrt smoking status',fontsize='30')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df['region'],y=df['charges'],hue='sex',data=df)
plt.show()

# %%
sns.set_theme(); np.random.seed(0)
x = df['age']
plt.figure(figsize=(20,5))
ax = sns.distplot(x)

# %%
sns.set_theme(); np.random.seed(0)
x = df['charges']
plt.figure(figsize=(20,5))
ax = sns.distplot(x)

# %%
sns.scatterplot(x=df['age'],y=df['charges'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['sex']=le.fit_transform(df['sex'])
df['smoker']=le.fit_transform(df['smoker'])
df['region']=le.fit_transform(df['region'])

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %% [markdown]
# Hence, the categorical columns've been converted into numerical columns.

# %%
plt.figure(figsize=(15,5))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Thus, we observe that correlation of sex and children is quite low as compared to other columns. Hence, we will drop these columns.

# %%
x=df.drop(columns=['charges','sex'])
y=df['charges']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import r2_score

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)

# %%
x_train_prediction=model.predict(x_train)
training_data_accuracy=r2_score(x_train_prediction,y_train)

print(training_data_accuracy)
# Out:
# 0.6605479947686939

# %%
x_test_prediction=model.predict(x_test)
test_data_accuracy=r2_score(x_test_prediction,y_test)

print(test_data_accuracy)
# Out:
# 0.6762993207764068

# %%
from sklearn.linear_model import Lasso

# %%
model = Lasso()
model.fit(x_train, y_train)
# Out:
# Lasso()

# %%
pred = model.predict(x_test)

# %%
x_train_prediction=model.predict(x_train)
training_data_accuracy=r2_score(x_train_prediction,y_train)

print(training_data_accuracy)
# Out:
# 0.6603911162225344

# %%
x_test_prediction=model.predict(x_test)
test_data_accuracy=r2_score(x_test_prediction,y_test)

print(test_data_accuracy)
# Out:
# 0.6761407487468136

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge()
model.fit(x_train, y_train)
# Out:
# Ridge()

# %%
pred = model.predict(x_test)

# %%
x_train_prediction=model.predict(x_train)
training_data_accuracy=r2_score(x_train_prediction,y_train)

print(training_data_accuracy)
# Out:
# 0.6570259514690927

# %%
x_test_prediction=model.predict(x_test)
test_data_accuracy=r2_score(x_test_prediction,y_test)

print(test_data_accuracy)
# Out:
# 0.672624451480208

# %%
from sklearn.linear_model import ElasticNet

# %%
model = ElasticNet()
model.fit(x_train, y_train)
# Out:
# ElasticNet()

# %%
pred = model.predict(x_test)

# %%
x_train_prediction=model.predict(x_train)
training_data_accuracy=r2_score(x_train_prediction,y_train)

print(training_data_accuracy)
# Out:
# -2.840080451280318

# %%
x_test_prediction=model.predict(x_test)
test_data_accuracy=r2_score(x_test_prediction,y_test)

print(test_data_accuracy)
# Out:
# -2.9682887094143875

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model = KNeighborsRegressor()
model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
pred = model.predict(x_test)

# %%
x_train_prediction=model.predict(x_train)
training_data_accuracy=r2_score(x_train_prediction,y_train)

print(training_data_accuracy)
# Out:
# -0.9601663252846715

# %%
x_test_prediction=model.predict(x_test)
test_data_accuracy=r2_score(x_test_prediction,y_test)

print(test_data_accuracy)
# Out:
# -2.5840617600796096

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
pred = model.predict(x_test)

# %%
x_train_prediction=model.predict(x_train)
training_data_accuracy=r2_score(x_train_prediction,y_train)

print(training_data_accuracy)
# Out:
# 0.9999991799307156

# %%
x_test_prediction=model.predict(x_test)
test_data_accuracy=r2_score(x_test_prediction,y_test)

print(test_data_accuracy)
# Out:
# 0.7733324182135479

# %%
results={'model': [], 'r2_score': [], 'Rmse': []}

# %%
models=[LinearRegression(), Lasso(), Ridge(), ElasticNet(), KNeighborsRegressor(), 
        DecisionTreeRegressor()]

# %%
from sklearn.metrics import r2_score, mean_squared_error
for model in models:
    m=model
    m.fit(x_train, y_train)
    y_test_pred=m.predict(x_test)
    rmse=np.sqrt(mean_squared_error(y_test, y_test_pred))
    r2=r2_score(y_test, y_test_pred)
    results['model'].append(type(model).__name__)
    results['r2_score'].append(r2)
    results['Rmse'].append(rmse)

# %%
results_frame=pd.DataFrame(results)
results_frame.sort_values('r2_score', ascending=False)
# Out:
#                    model  r2_score          Rmse
# 5  DecisionTreeRegressor  0.781629   5723.695470
# 0       LinearRegression  0.761628   5980.065927
# 1                  Lasso  0.761622   5980.141702
# 2                  Ridge  0.761382   5983.155664
# 3             ElasticNet  0.382811   9622.492188
# 4    KNeighborsRegressor  0.095526  11648.677409

# %% [markdown]
# # Tuning

# %%
ridge_params={'alpha': [0.1, 0.01, 0.005, 0.05, 0.001 ,0.2, 0.3, 0.5, 0.8, 0.9, 1], 
                   'solver': ['auto', 'svd', 'cholesky']}
lasso_params={'alpha': [0.1, 0.01, 0.005, 0.05, 0.001 ,0.2, 0.3, 0.5, 0.8, 0.9, 1]}

# %%
def tuning(x, y, model, model_params):
    results=[]
    X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.25, random_state=42)
    clf=GridSearchCV(model, model_params, cv=5, return_train_score=True)
    clf.fit(X_train, Y_train)
    Y_test_pred=clf.predict(X_test)
    test_error=np.sqrt(mean_squared_error(Y_test, Y_test_pred))
    r2score=r2_score(Y_test, Y_test_pred)                                                  
    print(type(model).__name__)
    print('Rmse: {}'.format(test_error))
    print('r2_score: {}'.format(r2score))
    results.append({'model': type(model).__name__, 
                    'RMSE': test_error,
                    'R2 Score': r2score,
                    'best_score': clf.best_score_,
                    'best_params': clf.best_params_})
    return results

# %%
result1=tuning(x, y, Ridge(), ridge_params)
# Out:
# Ridge
# Rmse: 5932.137313883631
# r2_score: 0.7667838338309936

# %%
result2=tuning(x, y, Lasso(), lasso_params)
# Out:
# Lasso
# Rmse: 5929.549845149737
# r2_score: 0.7669872370574211
